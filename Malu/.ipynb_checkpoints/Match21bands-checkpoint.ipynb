# %% [markdown]
# # Libraries

# %%
import numpy           as np
import pandas          as pd
import astropy.io.fits as fits
import os

# %% [markdown]
# # Data

# %%
list_of_folders = ['LambdarGALEXFUV', 'LambdarGALEXNUV', 'LambdarSDSSu', 'LambdarSDSSg', 'LambdarSDSSr', 
                   'LambdarSDSSi', 'LambdarSDSSz', 'LambdarVIKINGZ', 'LambdarVIKINGY', 'LambdarVIKINGJ', 
                   'LambdarVIKINGH', 'LambdarVIKINGK', 'LambdarWISEW1', 'LambdarWISEW2', 'LambdarWISEW3', 
                   'LambdarWISEW4', 'LambdarPACS100', 'LambdarPACS160', 'LambdarSPIRE250', 'LambdarSPIRE350', 
                   'LambdarSPIRE500']

# %%
columns = ['LAMID', 'DFAflux', 'DFAErr', 'DeblendErr', 'ABMagDFA', 'ABMagErrDFA', 'MinApCorr', 'MaxApCorr', 
           'PhotometryWarning', 'PhotometryFlag']

# %%
folders_path = '/home/mlldantas/Surveys/GAMA-DR3/LambdarPhotometry'

# %%
df_saving_path = '/home/mlldantas/Projects/LINER_UV/Data/GAMA-DR3-Matches/Attempt02'

# %% [markdown]
# # Loop opening, matching, and saving the data!

# %%
for i in list_of_folders:
    folder_suffix = i.split('ar')[-1]
    fits_temp = fits.open(os.path.join(folders_path, i+'/'+i+'.fits'))
    data_temp = fits_temp[1].data
    my_dict_temp = {}
    for j in columns:
        if j=='LAMID':
            my_dict_temp[j] = np.array(data_temp[j]).byteswap().newbyteorder()
        else:
            my_dict_temp[j+'_'+folder_suffix] = np.array(data_temp[j]).byteswap().newbyteorder()
    if i == 'LambdarGALEXFUV':
        my_df = pd.DataFrame(my_dict_temp)
    else:
        my_df_temp = pd.DataFrame(my_dict_temp)
        my_df = pd.concat([my_df, my_df_temp], axis=1, join='inner')

# %%
for i in my_df.keys():
    print(i)
# Out:
# LAMID
# DFAflux_GALEXFUV
# DFAErr_GALEXFUV
# DeblendErr_GALEXFUV
# ABMagDFA_GALEXFUV
# ABMagErrDFA_GALEXFUV
# MinApCorr_GALEXFUV
# MaxApCorr_GALEXFUV
# PhotometryWarning_GALEXFUV
# PhotometryFlag_GALEXFUV
# LAMID
# DFAflux_GALEXNUV
# DFAErr_GALEXNUV
# DeblendErr_GALEXNUV
# ABMagDFA_GALEXNUV
# ABMagErrDFA_GALEXNUV
# MinApCorr_GALEXNUV
# MaxApCorr_GALEXNUV
# PhotometryWarning_GALEXNUV
# PhotometryFlag_GALEXNUV
# LAMID
# DFAflux_SDSSu
# DFAErr_SDSSu
# DeblendErr_SDSSu
# ABMagDFA_SDSSu
# ABMagErrDFA_SDSSu
# MinApCorr_SDSSu
# MaxApCorr_SDSSu
# PhotometryWarning_SDSSu
# PhotometryFlag_SDSSu
# LAMID
# DFAflux_SDSSg
# DFAErr_SDSSg
# DeblendErr_SDSSg
# ABMagDFA_SDSSg
# ABMagErrDFA_SDSSg
# MinApCorr_SDSSg
# MaxApCorr_SDSSg
# PhotometryWarning_SDSSg
# PhotometryFlag_SDSSg
# LAMID
# DFAflux_SDSSr
# DFAErr_SDSSr
# DeblendErr_SDSSr
# ABMagDFA_SDSSr
# ABMagErrDFA_SDSSr
# MinApCorr_SDSSr
# MaxApCorr_SDSSr
# PhotometryWarning_SDSSr
# PhotometryFlag_SDSSr
# LAMID
# DFAflux_SDSSi
# DFAErr_SDSSi
# DeblendErr_SDSSi
# ABMagDFA_SDSSi
# ABMagErrDFA_SDSSi
# MinApCorr_SDSSi
# MaxApCorr_SDSSi
# PhotometryWarning_SDSSi
# PhotometryFlag_SDSSi
# LAMID
# DFAflux_SDSSz
# DFAErr_SDSSz
# DeblendErr_SDSSz
# ABMagDFA_SDSSz
# ABMagErrDFA_SDSSz
# MinApCorr_SDSSz
# MaxApCorr_SDSSz
# PhotometryWarning_SDSSz
# PhotometryFlag_SDSSz
# LAMID
# DFAflux_VIKINGZ
# DFAErr_VIKINGZ
# DeblendErr_VIKINGZ
# ABMagDFA_VIKINGZ
# ABMagErrDFA_VIKINGZ
# MinApCorr_VIKINGZ
# MaxApCorr_VIKINGZ
# PhotometryWarning_VIKINGZ
# PhotometryFlag_VIKINGZ
# LAMID
# DFAflux_VIKINGY
# DFAErr_VIKINGY
# DeblendErr_VIKINGY
# ABMagDFA_VIKINGY
# ABMagErrDFA_VIKINGY
# MinApCorr_VIKINGY
# MaxApCorr_VIKINGY
# PhotometryWarning_VIKINGY
# PhotometryFlag_VIKINGY
# LAMID
# DFAflux_VIKINGJ
# DFAErr_VIKINGJ
# DeblendErr_VIKINGJ
# ABMagDFA_VIKINGJ
# ABMagErrDFA_VIKINGJ
# MinApCorr_VIKINGJ
# MaxApCorr_VIKINGJ
# PhotometryWarning_VIKINGJ
# PhotometryFlag_VIKINGJ
# LAMID
# DFAflux_VIKINGH
# DFAErr_VIKINGH
# DeblendErr_VIKINGH
# ABMagDFA_VIKINGH
# ABMagErrDFA_VIKINGH
# MinApCorr_VIKINGH
# MaxApCorr_VIKINGH
# PhotometryWarning_VIKINGH
# PhotometryFlag_VIKINGH
# LAMID
# DFAflux_VIKINGK
# DFAErr_VIKINGK
# DeblendErr_VIKINGK
# ABMagDFA_VIKINGK
# ABMagErrDFA_VIKINGK
# MinApCorr_VIKINGK
# MaxApCorr_VIKINGK
# PhotometryWarning_VIKINGK
# PhotometryFlag_VIKINGK
# LAMID
# DFAflux_WISEW1
# DFAErr_WISEW1
# DeblendErr_WISEW1
# ABMagDFA_WISEW1
# ABMagErrDFA_WISEW1
# MinApCorr_WISEW1
# MaxApCorr_WISEW1
# PhotometryWarning_WISEW1
# PhotometryFlag_WISEW1
# LAMID
# DFAflux_WISEW2
# DFAErr_WISEW2
# DeblendErr_WISEW2
# ABMagDFA_WISEW2
# ABMagErrDFA_WISEW2
# MinApCorr_WISEW2
# MaxApCorr_WISEW2
# PhotometryWarning_WISEW2
# PhotometryFlag_WISEW2
# LAMID
# DFAflux_WISEW3
# DFAErr_WISEW3
# DeblendErr_WISEW3
# ABMagDFA_WISEW3
# ABMagErrDFA_WISEW3
# MinApCorr_WISEW3
# MaxApCorr_WISEW3
# PhotometryWarning_WISEW3
# PhotometryFlag_WISEW3
# LAMID
# DFAflux_WISEW4
# DFAErr_WISEW4
# DeblendErr_WISEW4
# ABMagDFA_WISEW4
# ABMagErrDFA_WISEW4
# MinApCorr_WISEW4
# MaxApCorr_WISEW4
# PhotometryWarning_WISEW4
# PhotometryFlag_WISEW4
# LAMID
# DFAflux_PACS100
# DFAErr_PACS100
# DeblendErr_PACS100
# ABMagDFA_PACS100
# ABMagErrDFA_PACS100
# MinApCorr_PACS100
# MaxApCorr_PACS100
# PhotometryWarning_PACS100
# PhotometryFlag_PACS100
# LAMID
# DFAflux_PACS160
# DFAErr_PACS160
# DeblendErr_PACS160
# ABMagDFA_PACS160
# ABMagErrDFA_PACS160
# MinApCorr_PACS160
# MaxApCorr_PACS160
# PhotometryWarning_PACS160
# PhotometryFlag_PACS160
# LAMID
# DFAflux_SPIRE250
# DFAErr_SPIRE250
# DeblendErr_SPIRE250
# ABMagDFA_SPIRE250
# ABMagErrDFA_SPIRE250
# MinApCorr_SPIRE250
# MaxApCorr_SPIRE250
# PhotometryWarning_SPIRE250
# PhotometryFlag_SPIRE250
# LAMID
# DFAflux_SPIRE350
# DFAErr_SPIRE350
# DeblendErr_SPIRE350
# ABMagDFA_SPIRE350
# ABMagErrDFA_SPIRE350
# MinApCorr_SPIRE350
# MaxApCorr_SPIRE350
# PhotometryWarning_SPIRE350
# PhotometryFlag_SPIRE350
# LAMID
# DFAflux_SPIRE500
# DFAErr_SPIRE500
# DeblendErr_SPIRE500
# ABMagDFA_SPIRE500
# ABMagErrDFA_SPIRE500
# MinApCorr_SPIRE500
# MaxApCorr_SPIRE500
# PhotometryWarning_SPIRE500
# PhotometryFlag_SPIRE500

# %% [markdown]
# # Retrieving CATAID

# %%
fuv_to_nir = fits.open(os.path.join(folders_path, 'LambdarInputCatUVOptNIR/LambdarInputCatUVOptNIR.fits'))

# %%
ftn_data = fuv_to_nir[1].data

# %%
ftn_data['CATAID']
# Out:
# array([100000, 100001, 100002, ...,   -999,   -999,   -999], dtype=int32)

# %%
cataid_dictionary = {}
cataid_dictionary['LAMID'] = ftn_data['LAMID'].byteswap().newbyteorder()
cataid_dictionary['CATAID'] = ftn_data['CATAID'].byteswap().newbyteorder()

# %%
cataid_dictionary
# Out:
# {'LAMID': chararray(['100000', '100001', '100002', ..., 'NewID_97', 'NewID_98',
#             'NewID_99'], dtype='>U9'),
#  'CATAID': array([100000, 100001, 100002, ...,   -999,   -999,   -999], dtype=int32)}

# %%
cataid_df = pd.DataFrame(cataid_dictionary)

# %%
cataid_df
# Out:
#              LAMID  CATAID
# 0        100000     100000
# 1        100001     100001
# 2        100002     100002
# 3        100003     100003
# 4        100004     100004
# ...            ...     ...
# 1829036  NewID_95     -999
# 1829037  NewID_96     -999
# 1829038  NewID_97     -999
# 1829039  NewID_98     -999
# 1829040  NewID_99     -999
#
# [1829041 rows x 2 columns]

# %%
my_df = pd.concat([cataid_df, my_df], axis=1, join='inner')

# %%
my_df = my_df.loc[:,~my_df.columns.duplicated()]

# %%
my_df.to_csv(os.path.join(df_saving_path, 'GALEXFUV_to_SPIRE500.csv'), index=False)

# %%
my_df
# Out:
#             LAMID   CATAID  DFAflux_GALEXFUV  DFAErr_GALEXFUV  \
# 0       100000      100000      2.479260e-06     7.963562e-07
# 1       100001      100001      0.000000e+00     8.161955e-07
# 2       100002      100002      1.556696e-06     1.300735e-06
# 3       100003      100003      5.865144e-06     8.889841e-07
# 4       100004      100004      1.493697e-05     6.755653e-07
# ...           ...      ...               ...              ...
# 179265  3079618    3079618      2.102421e-06     5.410137e-07
# 179266  3079619    3079619      7.015385e-07     5.754799e-07
# 179267  3079620    3079620      2.138356e-06     7.189455e-07
# 179268  3079621    3079621      1.965754e-07     7.438714e-07
# 179269  3079622    3079622      0.000000e+00     6.606187e-07
#
#         DeblendErr_GALEXFUV  ABMagDFA_GALEXFUV  ABMagErrDFA_GALEXFUV  \
# 0              2.617298e-08          22.914194              6.236599
# 1              3.193431e-07        -999.000000           -999.000000
# 2              5.138221e-09          23.419491             10.675610
# 3              1.193218e-07          21.979303              3.346163
# 4              1.844990e-07          20.964342              1.927995
# ...                     ...                ...                   ...
# 179265         4.116245e-08          23.093201              6.278263
# 179266         2.639060e-08          24.284872             12.575424
# 179267         6.235039e-08          23.074800              6.556540
# 179268         6.312626e-09          25.666178             46.639297
# 179269         2.601245e-07        -999.000000           -999.000000
#
#         MinApCorr_GALEXFUV  MaxApCorr_GALEXFUV PhotometryWarning_GALEXFUV  \
# 0                 1.293492            1.753233                        -
# 1                 1.370058            1.820509                        QI
# 2                 1.142964            1.506265                        -
# 3                 1.260873            1.698566                        -
# 4                 1.418465            1.922459                        -
# ...                    ...                 ...                        ...
# 179265            1.672126            2.074637                        -
# 179266            1.591398            2.013438                        -
# 179267            1.478607            1.884989                        Q
# 179268            1.326418            1.793108                        Q
# 179269            1.520032            1.967411                        QI
#
#         ...  PhotometryFlag_SPIRE350  DFAflux_SPIRE500  DFAErr_SPIRE500  \
# 0       ...                        9          0.000000         0.010083
# 1       ...                        0          0.000000         0.009521
# 2       ...                        8          0.000000         0.009058
# 3       ...                        0          0.000000         0.010249
# 4       ...                        9          0.000000         0.007129
# ...     ...                      ...               ...              ...
# 179265  ...                        0          0.013021         0.031837
# 179266  ...                        0          0.015413         0.006417
# 179267  ...                        0          0.000326         0.022946
# 179268  ...                        8          0.004731         0.010277
# 179269  ...                        0          0.018105         0.034120
#
#         DeblendErr_SPIRE500  ABMagDFA_SPIRE500  ABMagErrDFA_SPIRE500  \
# 0                  0.007181        -999.000000           -999.000000
# 1                  0.001290        -999.000000           -999.000000
# 2                  0.004547        -999.000000           -999.000000
# 3                  0.004001        -999.000000           -999.000000
# 4                  0.000686        -999.000000           -999.000000
# ...                     ...                ...                   ...
# 179265             0.031273          13.613353              1.231480
# 179266             0.000876          13.430253              0.413952
# 179267             0.017243          17.616381             31.007385
# 179268             0.008339          14.712654              1.461030
# 179269             0.032927          13.255475              0.958745
#
#         MinApCorr_SPIRE500  MaxApCorr_SPIRE500 PhotometryWarning_SPIRE500  \
# 0                 2.103503            2.103503                        QSI
# 1                 2.154206            2.154206                        QSI
# 2                 2.173464            2.173464                        QI
# 3                 2.167544            2.167544                        QI
# 4                 2.204533            2.204533                        QI
# ...                    ...                 ...                        ...
# 179265            2.144008            2.144008                        -
# 179266            2.205903            2.205903                        -
# 179267            2.160931            2.160931                        -
# 179268            2.210014            2.210014                        Q
# 179269            2.089865            2.089865                        -
#
#         PhotometryFlag_SPIRE500
# 0                            13
# 1                            13
# 2                             9
# 3                             9
# 4                             9
# ...                         ...
# 179265                        0
# 179266                        0
# 179267                        0
# 179268                        8
# 179269                        0
#
# [179270 rows x 191 columns]

# %% [markdown]
# # Additional match with the other catalogues (pre-matched via TopCat)

# %%
vacs_match = pd.read_csv(os.path.join(df_saving_path, 'Match02_small.csv'))

# %%
my_vacs_df = pd.concat([my_df, vacs_match], axis=1, join='inner')

# %%
my_vacs_df = my_vacs_df.loc[:,~my_vacs_df.columns.duplicated()]

# %%
my_vacs_df
# Out:
#             LAMID   CATAID  DFAflux_GALEXFUV  DFAErr_GALEXFUV  \
# 0       100000      100000      2.479260e-06     7.963562e-07
# 1       100001      100001      0.000000e+00     8.161955e-07
# 2       100002      100002      1.556696e-06     1.300735e-06
# 3       100003      100003      5.865144e-06     8.889841e-07
# 4       100004      100004      1.493697e-05     6.755653e-07
# ...           ...      ...               ...              ...
# 119463  3021558    3021558      2.274809e-07     5.091504e-07
# 119464  3021559    3021559      0.000000e+00     5.629622e-07
# 119465  302156      302156      1.878591e-06     5.459135e-07
# 119466  3021560    3021560      0.000000e+00     4.806578e-07
# 119467  3021561    3021561      1.676689e-06     5.288210e-07
#
#         DeblendErr_GALEXFUV  ABMagDFA_GALEXFUV  ABMagErrDFA_GALEXFUV  \
# 0              2.617298e-08          22.914194              6.236599
# 1              3.193431e-07        -999.000000           -999.000000
# 2              5.138221e-09          23.419491             10.675610
# 3              1.193218e-07          21.979303              3.346163
# 4              1.844990e-07          20.964342              1.927995
# ...                     ...                ...                   ...
# 119463         2.018976e-08          25.507637             41.344063
# 119464         2.982534e-08        -999.000000           -999.000000
# 119465         5.455340e-07          23.215420              5.081846
# 119466         1.257188e-07        -999.000000           -999.000000
# 119467         2.600182e-08          23.338869              6.545708
#
#         MinApCorr_GALEXFUV  MaxApCorr_GALEXFUV PhotometryWarning_GALEXFUV  \
# 0                 1.293492            1.753233                        -
# 1                 1.370058            1.820509                        QI
# 2                 1.142964            1.506265                        -
# 3                 1.260873            1.698566                        -
# 4                 1.418465            1.922459                        -
# ...                    ...                 ...                        ...
# 119463            1.246210            1.692332                        Q
# 119464            1.425687            1.873708                        QI
# 119465            1.292771            1.752383                        -
# 119466            1.372954            1.813215                        QI
# 119467            1.352022            1.807591                        -
#
#         ...      A_z  A_Y_UKIDSS  A_J_UKIDSS  A_H_UKIDSS  A_K_UKIDSS  \
# 0       ...  0.03305     0.02706     0.01986     0.01291     0.00804
# 1       ...  0.03272     0.02679     0.01967     0.01279     0.00796
# 2       ...  0.03184     0.02607     0.01914     0.01244     0.00775
# 3       ...  0.03461     0.02834     0.02080     0.01352     0.00842
# 4       ...  0.03323     0.02721     0.01998     0.01299     0.00809
# ...     ...      ...         ...         ...         ...         ...
# 119463  ...  0.04419     0.03618     0.02656     0.01727     0.01076
# 119464  ...  0.03202     0.02622     0.01925     0.01252     0.00779
# 119465  ...  0.03004     0.02459     0.01806     0.01174     0.00731
# 119466  ...  0.03693     0.03024     0.02220     0.01443     0.00899
# 119467  ...  0.03337     0.02733     0.02006     0.01304     0.00812
#
#         A_Z_VIKING  A_Y_VIKING  A_J_VIKING A_H_VIKING  A_K_VIKING
# 0          0.03821     0.02927     0.02074    0.01323     0.00867
# 1          0.03783     0.02898     0.02053    0.01310     0.00858
# 2          0.03681     0.02820     0.01998    0.01274     0.00835
# 3          0.04001     0.03065     0.02171    0.01385     0.00908
# 4          0.03842     0.02944     0.02085    0.01330     0.00872
# ...            ...         ...         ...        ...         ...
# 119463     0.05109     0.03914     0.02773    0.01769     0.01159
# 119464     0.03703     0.02836     0.02009    0.01282     0.00840
# 119465     0.03473     0.02661     0.01885    0.01202     0.00788
# 119466     0.04270     0.03271     0.02317    0.01478     0.00969
# 119467     0.03859     0.02956     0.02094    0.01336     0.00876
#
# [119468 rows x 509 columns]

# %%
my_vacs_df.to_csv(os.path.join(df_saving_path, 'GALEXFUV_to_SPIRE500_VACs.csv'), index=False)

# %%
for i in my_vacs_df.keys():
    if i.split('_')[0]=='ABMagDFA':
        print(i)
# Out:
# ABMagDFA_GALEXFUV
# ABMagDFA_GALEXNUV
# ABMagDFA_SDSSu
# ABMagDFA_SDSSg
# ABMagDFA_SDSSr
# ABMagDFA_SDSSi
# ABMagDFA_SDSSz
# ABMagDFA_VIKINGZ
# ABMagDFA_VIKINGY
# ABMagDFA_VIKINGJ
# ABMagDFA_VIKINGH
# ABMagDFA_VIKINGK
# ABMagDFA_WISEW1
# ABMagDFA_WISEW2
# ABMagDFA_WISEW3
# ABMagDFA_WISEW4
# ABMagDFA_PACS100
# ABMagDFA_PACS160
# ABMagDFA_SPIRE250
# ABMagDFA_SPIRE350
# ABMagDFA_SPIRE500

# %% [markdown]
# # Selecting one galaxy to test Prospect

# %%
bands = []
fluxes = []
errors = []
for i in range(len(my_df.keys())):
    if my_df.keys()[i].split('_')[0]=='DFAflux':
        if my_df.keys()[i].split('_')[1]=='SDSSz':
            continue
        else:
            bands.append(my_df.keys()[i].split('_')[1])
            fluxes.append(my_df[my_df.keys()[i]].values[0])
    elif my_df.keys()[i].split('_')[0]=='DFAErr':
        if my_df.keys()[i].split('_')[1]=='SDSSz':
            continue
        else:
            errors.append(my_df[my_df.keys()[i]].values[0])
        
print(len(fluxes))
print(len(errors))
print(len(bands))
# Out:
# 20
# 20
# 20

# %%
one_g = {}
one_g['bands'] = bands
one_g['fluxes'] = fluxes
one_g['errors'] = errors
one_galaxy = pd.DataFrame(one_g)

# %%
one_galaxy
# Out:
#        bands    fluxes        errors
# 0   GALEXFUV  0.000002  7.963562e-07
# 1   GALEXNUV  0.000006  8.580051e-07
# 2      SDSSu  0.000013  2.223605e-06
# 3      SDSSg  0.000021  9.610321e-07
# 4      SDSSr  0.000043  1.547137e-06
# 5      SDSSi  0.000059  1.842910e-06
# 6    VIKINGZ  0.000069  3.057852e-06
# 7    VIKINGY  0.000075  4.772358e-06
# 8    VIKINGJ  0.000084  4.251835e-06
# 9    VIKINGH  0.000078  3.614882e-05
# 10   VIKINGK  0.000108  2.147133e-05
# 11    WISEW1  0.000098  2.793198e-05
# 12    WISEW2  0.000072  3.583351e-05
# 13    WISEW3  0.000094  1.972682e-04
# 14    WISEW4  0.000000  4.639644e-04
# 15   PACS100  0.000000  2.763258e-02
# 16   PACS160  0.000000  2.218256e-02
# 17  SPIRE250  0.006759  3.835647e-03
# 18  SPIRE350  0.000000  1.170291e-02
# 19  SPIRE500  0.000000  1.008292e-02

# %%
one_galaxy.to_csv(os.path.join('/home/mlldantas/Projects/LINER_UV/Data/SEDfitTest', 'one_galaxy.csv'), 
                  index=False)
