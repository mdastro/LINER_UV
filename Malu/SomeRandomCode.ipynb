# %%
plotpars_1x1 = {'axes.linewidth': 1.,
                'axes.labelsize': 18,
                'xtick.labelsize': 18,
                'ytick.labelsize': 18,
                'legend.frameon': True,
                'legend.framealpha': 0.85,
                'legend.edgecolor': 'black',
                'legend.loc': 'upper right',
                'legend.fontsize': 12,
                'font.size': 12,
                'figure.figsize': (7.,5.),
                'image.cmap': 'ocean_r'
               }

# %% [markdown]
# # Libraries

# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data

# %%
data_pandas = pd.read_csv('../../Data/Match07_smalldoubleclean_emlines.csv')

# %%
data_pandas
# Out:
#        CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 0      585610  588848899914268877     183.6357    -0.180381          3.5
# 1      585622  588848899914334317     183.7372    -0.046642          3.5
# 2      585630  588848899914334392     183.8403    -0.045170          3.5
# 3      585637  588848899914334460     183.7989    -0.059996          3.5
# 4      585667  588848899914399953     183.8874    -0.076773          3.5
# ...       ...                 ...          ...          ...          ...
# 14326  585409  588848899913810261     182.6236    -0.118058          3.5
# 14327  585436  588848899913875691     182.8106    -0.015192          3.5
# 14328  585450  588848899913875754     182.8055    -0.045858          3.5
# 14329  585465  588848899913941263     182.8369    -0.154758          3.5
# 14330  585512  588848899914006854     182.9919    -0.122844          3.5
#
#        PETRO_RADIUS  MAG_PETRO_u  MAGERR_PETRO_u  FLAGS_u  MAG_PETRO_g  ...  \
# ...

# %%
pradius = data_pandas['PETRO_RADIUS'].values

# %%
pradius
# Out:
# array([4.62, 4.62, 4.62, ..., 5.28, 5.28, 5.94])

# %%
plt.rcParams.update(plotpars_1x1)
plt.scatter(data_pandas['MAG_ABSOLUTE_FUV'], data_pandas['MAG_AB_FUV']-data_pandas['MAG_AB_NUV'], color='blue', 
         marker='o', alpha=0.1)
plt.xlabel(r"M$_{FUV}$")
plt.ylabel(r"FUV-NUV")
plt.show()

# %%
data_pandas.describe()
# Out:
#              CATAID  OBJID_SDSSDR7   ALPHA_J2000   DELTA_J2000   KRON_RADIUS  \
# count  1.433100e+04   1.433100e+04  14331.000000  14331.000000  14331.000000
# mean   4.453118e+05   5.879757e+17    187.171501     -7.368213     -4.094766
# std    6.917857e+05   4.607557e+14    283.987375    276.937752    277.024920
# min    6.806000e+03   5.877230e+17  -9999.000000  -9999.000000  -9999.000000
# 25%    1.432110e+05   5.877250e+17    179.121000     -0.951681      3.500000
# 50%    2.983120e+05   5.877260e+17    213.693700      0.228232      3.500000
# 75%    5.115125e+05   5.877300e+17    218.541750      1.459151      3.520000
# max    3.914319e+06   5.888489e+17    223.498200      2.999892      8.070000
#
#        PETRO_RADIUS   MAG_PETRO_u  MAGERR_PETRO_u       FLAGS_u   MAG_PETRO_g  \
# count  14331.000000  14331.000000    14331.000000  14331.000000  14331.000000
# mean      -2.508484     16.025940       -4.085258     -6.276813     12.233729
# ...

# %%
data_pandas.keys()
# Out:
# Index(['CATAID', 'OBJID_SDSSDR7', 'ALPHA_J2000', 'DELTA_J2000', 'KRON_RADIUS',
#        'PETRO_RADIUS', 'MAG_PETRO_u', 'MAGERR_PETRO_u', 'FLAGS_u',
#        'MAG_PETRO_g',
#        ...
#        'MAG_ABSOLUTE_I', 'MAG_ABSOLUTE_Z', 'MAG_ABSOLUTE_Y', 'MAG_ABSOLUTE_J',
#        'MAG_ABSOLUTE_H', 'MAG_ABSOLUTE_K', 'UV_CLASS_YI2011', 'TYPE',
#        'BPT_CLASS', 'WHAN_CLASS'],
#       dtype='object', length=164)

# %%
for i in data_pandas.keys():
    print(i)
# Out:
# CATAID
# OBJID_SDSSDR7
# ALPHA_J2000
# DELTA_J2000
# KRON_RADIUS
# PETRO_RADIUS
# MAG_PETRO_u
# MAGERR_PETRO_u
# FLAGS_u
# MAG_PETRO_g
# MAGERR_PETRO_g
# FLAGS_g
# MAG_PETRO_r
# MAGERR_PETRO_r
# FLAGS_r
# MAG_PETRO_i
# MAGERR_PETRO_i
# FLAGS_i
# MAG_PETRO_z
# MAGERR_PETRO_z
# FLAGS_z
# MAG_PETRO_X
# MAGERR_PETRO_X
# FLAGS_X
# MAG_PETRO_Y
# MAGERR_PETRO_Y
# FLAGS_Y
# MAG_PETRO_J
# MAGERR_PETRO_J
# FLAGS_J
# MAG_PETRO_H
# MAGERR_PETRO_H
# FLAGS_H
# MAG_PETRO_K
# MAGERR_PETRO_K
# FLAGS_K
# FLAGS
# PSFMAG_R
# FIBERMAG_R
# FLAGS_R_SDSS
# PETRORAD_R
# PETROR90_R
# PETROR50_R
# PETROMAG_R
# MODELMAG_U
# MODELMAG_G
# MODELMAG_R
# MODELMAG_I
# MODELMAG_Z
# STATUS
# BEST_MAG_NUV
# BEST_MAGERR_NUV
# BEST_MAG_FUV
# BEST_MAGERR_FUV
# BEST_METHOD
# NMATCHUV
# NMATCHOPT
# NUVFLAG
# FUVFLAG
# NN_DIST
# NN_NMATCH4
# NN_MANY2ONE
# NN_SFLAGS_NUV
# NN_SFLAGS_FUV
# KCORR_FUV
# KCORR_NUV
# KCORR_U
# KCORR_G
# KCORR_R
# KCORR_I
# KCORR_Z
# KCORR_Y
# KCORR_J
# KCORR_H
# KCORR_K
# CHI2
# MASS
# INTSFH
# ...

# %%
data_pandas['MAG_ABSOLUTE_FUV'].describe().loc['50%']
# Out:
# -17.0277099804

# %%
data_pandas.plot(y='MAG_ABSOLUTE_FUV', kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data_pandas['HA_EW_COMP']
# Out:
# 0        31.449660
# 1        36.938120
# 2        44.878830
# 3         0.187773
# 4        18.575180
#            ...
# 14326     2.240695
# 14327    43.521560
# 14328    32.957360
# 14329    24.863380
# 14330    11.066700
# Name: HA_EW_COMP, Length: 14331, dtype: float64

# %%
data_uvupturn = data_pandas[data_pandas['UV_CLASS_YI2011']=='UV_UPTURN']

# %%
data_uvupturn
# Out:
#        CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 126    594994  588848899931439415     222.9286    -0.152468         3.50
# 136    598961  588848900427481399     129.5402     0.382411         3.50
# 188    600232  588848900429578535     134.3863     0.325479         3.50
# 243    609264  588848900447207626     174.6825     0.215878         3.50
# 257    609352  588848900447469792     175.2976     0.220674         3.53
# ...       ...                 ...          ...          ...          ...
# 14018  238680  587726014547362147     215.0042     1.638182         3.50
# 14045  238896  587726014547624265     215.5956     1.718073         3.50
# 14048  238934  587726014547689788     215.7093     1.588789         3.50
# 14177  240455  587726014550704346     222.6621     1.356651         3.50
# 14233  574429  588848899893297496     135.6948    -0.151438         3.50
#
#        PETRO_RADIUS  MAG_PETRO_u  MAGERR_PETRO_u  FLAGS_u  MAG_PETRO_g  ...  \
# ...

# %%
data_pandas[data_pandas['UV_CLASS_YI2011']!='RSF']
# Out:
#        CATAID       OBJID_SDSSDR7  ALPHA_J2000  DELTA_J2000  KRON_RADIUS  \
# 51     593695  588848899929080146     217.5533    -0.056942          3.5
# 122    594913  588848899931242710     222.3814    -0.031320          3.5
# 126    594994  588848899931439415     222.9286    -0.152468          3.5
# 136    598961  588848900427481399     129.5402     0.382411          3.5
# 188    600232  588848900429578535     134.3863     0.325479          3.5
# ...       ...                 ...          ...          ...          ...
# 14233  574429  588848899893297496     135.6948    -0.151438          3.5
# 14253  575512  588848899895263570     140.2724    -0.200350          4.0
# 14292  584520  588848899912499466     179.6385    -0.101355          3.5
# 14307  584929  588848899912892792     180.4991    -0.055015          3.5
# 14322  585358  588848899913744639     182.4603    -0.123035          3.5
#
#        PETRO_RADIUS  MAG_PETRO_u  MAGERR_PETRO_u  FLAGS_u  MAG_PETRO_g  ...  \
# ...

# %% [markdown]
# # Cleaning my data

# %%
data_clean = data_pandas[(data_pandas['HA_FLUX_COMP']!=0)&(data_pandas['NIIR_FLUX_COMP']!=0)
                         &(data_pandas['NIIR_FLUX_COMP']!=-99999.)]

# %%
plt.hist(data_clean['NIIR_FLUX_COMP'])
plt.show()

# %% [markdown]
# # Creating a new dataframe

# %%
heatmap_uvup = {}
heatmap_uvup['MAG_ABSOLUTE_FUV'] = data_uvupturn['MAG_ABSOLUTE_FUV'].values
heatmap_uvup['MAG_ABSOLUTE_NUV'] = data_uvupturn['MAG_ABSOLUTE_NUV'].values
heatmap_uvup['HA_EW_COMP'] = data_uvupturn['HA_EW_COMP'].values

# %%
heatmap_uvup_df = pd.DataFrame(heatmap_uvup)

# %%
heatmap_uvup_df
# Out:
#      MAG_ABSOLUTE_FUV  MAG_ABSOLUTE_NUV  HA_EW_COMP
# 0          -14.894133        -14.849546    2.864196
# 1          -15.078476        -15.683049    0.000000
# 2          -15.218719        -15.222842    0.241781
# 3          -16.467636        -15.418777    3.732696
# 4          -16.970764        -16.535511   10.103500
# ..                ...               ...         ...
# 205        -16.107770        -16.183946    3.611317
# 206        -14.270698        -13.960009    2.174798
# 207        -14.098747        -14.802818    5.045144
# 208        -14.891609        -15.286578    0.184613
# 209        -15.709680        -16.402302    0.974930
#
# [210 rows x 3 columns]

# %%
sns.heatmap(data=heatmap_uvup_df.corr(method='kendall'), vmin=-1., vmax=1.)
plt.show()

# %%
plt.scatter(np.log10(data_clean['HA_EW_COMP']), data_clean['MAG_ABSOLUTE_FUV'], label='entire data')
plt.axvline(x=np.log10(3), color='black', linestyle='--')
plt.axhline(y=-12.5, color='#2ca25f', linestyle=':', lw=5)
plt.xlim([-2.1, 2.5])
plt.legend(loc='best', bbox_to_anchor=(0.5, 1), ncol=1) 
plt.show()
# Out:
# /work/mlldantas/anaconda3/lib/python3.8/site-packages/pandas/core/arraylike.py:358: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
stellar_mass = data_clean['logmstar']

# %%
sns.kdeplot(stellar_mass)
plt.xlim([6,13])
plt.show()

# %%
bin_size = np.arange(start=6, stop=13, step=0.5)

# %%
bin_size
# Out:
# array([ 6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5, 11. ,
#        11.5, 12. , 12.5])

# %%
stellar_mass.describe().loc['25%']
# Out:
# 9.859634

# %%
stellar_mass.describe(percentiles=[0.025, 0.25, 0.5, 0.75, 0.975])
# Out:
# count    13213.000000
# mean        10.139461
# std          3.051530
# min        -99.000000
# 2.5%         9.067488
# 25%          9.859634
# 50%         10.282630
# 75%         10.634130
# 97.5%       11.097905
# max         12.321590
# Name: logmstar, dtype: float64
