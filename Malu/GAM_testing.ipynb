# %% [markdown]
# # Libraries

# %%
import numpy             as np
import pandas            as pd
import matplotlib.pyplot as plt
import statsmodels.api   as sm
import scipy             as s
import arviz
import pystan
import time

# %% [markdown]
# # Data

# %%
x_var = np.random.normal(loc=40, scale=10, size=1000)

# %%
y_var = x_var/np.random.gamma(shape=10, scale=10, size=1000)

# %%
plt.scatter(x_var, y_var)
plt.show()

# %%
s.stats.spearmanr(x_var, y_var)
# Out:
# SpearmanrResult(correlation=0.602923538923539, pvalue=5.139658628789979e-100)
